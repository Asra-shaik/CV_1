# %%
import numpy as np
import matplotlib.pyplot as plt
img= cv2.imread("C://Users//Public//Pictures//Sample Pictures//Penguins.jpg",1)
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import matplotlib.pyplot as plt
img= cv2.imread("C://Users//Public//Pictures//Sample Pictures//Penguins.jpg",1)
plt.imshow(img, cmap='gray', interpolation= 'bicubic')
plt.plot([50,100],[80,100],'c')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
img= cv2.imread("C://Users//Public//Pictures//Sample Pictures//Penguins.jpg",0)
plt.imshow(img, cmap='gray', interpolation= 'bicubic')
plt.plot([50,100],[80,100],'c')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
img= cv2.imread("C://Users//Public//Pictures//Sample Pictures//Penguins.jpg",-1)
plt.imshow(img, cmap='gray', interpolation= 'bicubic')
plt.plot([50,100],[80,100],'c')
plt.show()
